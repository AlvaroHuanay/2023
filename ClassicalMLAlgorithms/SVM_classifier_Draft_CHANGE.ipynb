# %%
import numpy as np

# %%
class SVM_Classifier():
  
  def __init__(self, learning_rate, n_iterations, lambda_parameter):

    self.learning_rate=learning_rate
    self.n_iterations=n_iterations
    self.lambda_parameter=lambda_parameter
  def fit(self, X, Y):

    self.m, self.n=X.shape
    self.w=np.zeros(self.n)
    self.b=0
    self.X=X
    self.Y=Y

    for i in range(self.n_iterations):
      self.update_weights()

  def update_weights(self):

    y_label=np.where(self.Y <= 0, -1, 1)

    for index, x_i in enumerate(self.X):

      condition=(y_label[index]*(np.dot(x_i, self.w)-self.b)>=1).astype(bool)
      #print(condition)
      #print(type(condition))
      if (np.all(condition)):

        dw=2*self.lambda_parameter*self.w
        db=0
      
      else:

        dw=2*self.lambda_parameter*self.w-np.dot(x_i, y_label[index])
        db=y_label[index]

      self.w=self.w-self.learning_rate*dw
      self.b=self.w-self.learning_rate*db

  def predict(self,X):
      predicted_labels=[]
      print("w^T: ", (np.transpose(self.w.reshape(-1,30))).shape)
      print("X: ", X.reshape(-1,30).shape)
      print("b: ", self.b.reshape(-1,30).shape)
      for i in range(len(X)):
        #No me fío de cómo he calculado b, quiero decir, la b ahora mismo (usé la media) porque la b antes (que estaba bien) era
        #Para cada variable (de las 30 que había), para cada ejemplo, puse b media en el siguiente comando
        output=np.dot(X.reshape(-1,30),np.transpose(self.w.reshape(-1,30)))-np.full((len(X), 1), np.mean(self.b))
      print("output shape: ", output.shape)
      predicted_labels=np.sign(output)
      predicted_labels = np.array(predicted_labels)
      print(predicted_labels.shape)
      y_hat=np.where(predicted_labels <=-1, 0, 1)

      return y_hat

# %%
w=np.ones((30,1))

# %%
np.dot(X_train.reshape(-1,30),w).shape
# Out:
# (455, 1)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

# %%
breast_cancer=load_breast_cancer()
df=pd.DataFrame(breast_cancer.data, columns=breast_cancer.feature_names)
df["target"]=breast_cancer.target

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
print("Dataframe shape (examples, features): ", df.shape)
print("Target values: \n", df["target"].value_counts())
df.describe()
# Out:
# Dataframe shape (examples, features):  (569, 31)
# Target values: 1    357
# 0    212
# Name: target, dtype: int64
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
X=df.drop(columns="target", axis=1)
Y=df["target"]
scaler=StandardScaler()
scaler.fit(X)
standarized_data=scaler.transform(X)
X=standarized_data
X_train, X_test, y_train, y_test= train_test_split(X, Y, test_size=0.2, random_state=41)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (569, 30) (455, 30) (114, 30)

# %%
classifier=SVM_Classifier(learning_rate=0.01, n_iterations=1000, lambda_parameter=0.01)
classifier.fit(X_train, y_train)

# %%
y_train_pred=pd.DataFrame(classifier.predict(X_train))
# Out:
# w^T:  (30, 1)
# X:  (455, 30)
# b:  (1, 30)
# output shape:  (455, 1)
# (455, 1)

# %%
y_train
# Out:
# 475    1
# 298    1
# 220    1
# 549    1
# 567    0
#       ..
# 469    1
# 407    1
# 243    1
# 321    0
# 80     1
# Name: target, Length: 455, dtype: int64

# %%
print(y_train_pred.shape)
print(y_train.shape)
# Out:
# (455, 1)
# (455,)

# %%
train_accuracy=accuracy_score(y_train, y_train_pred)
print(train_accuracy)
#Demasiado sospechoso
# Out:
# 0.9846153846153847

# %%
y_test_pred=classifier.predict(X_test)
test_accuracy=accuracy_score(y_test, y_test_pred)
print(test_accuracy)
#No me parece bien esto la accuracy tendría que ser un poco menor
# Out:
# w^T:  (30, 1)
# X:  (114, 30)
# b:  (1, 30)
# output shape:  (114, 1)
# (114, 1)
# 0.9912280701754386
